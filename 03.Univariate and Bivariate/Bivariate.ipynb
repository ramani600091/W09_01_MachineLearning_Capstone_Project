# %% [markdown]
# # Declaring Libraries

# %%
import pandas as pd
import UnivariateFunctions as dpm
import warnings
warnings.filterwarnings("ignore")

# %%
import seaborn as sns

# %% [markdown]
# # Get Processed Data

# %%
dataset,df,ind,dep,x_train,x_test,y_train,ytest= dpm.getProcessedData()
print(dataset)
# Out:
#          age  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 107    14499     164      48    110     70            1     2    1.0   1.0
# 230    23376     175      75    180    100            3     1    1.0   1.0
# 407    23262     162      70    130     70            1     1    1.0   1.0
# 462    21993     175      92    120     80            3     1    1.0   1.0
# 565    16488     175      95    120     90            1     1    1.0   1.0
# ...      ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69277  18709     169      76    130     80            1     2    1.0   1.0
# 69391  20230     165      72    140     90            1     1    1.0   1.0
# 69482  21211     165      69    140     90            1     1    1.0   1.0
# 69794  19606     170      77    150     80            1     1    1.0   1.0
# 69953  17373     173      69    110     70            1     1    1.0   1.0
#
#        active  cardio  gender_Male
# 107       1.0     1.0            0
# 230       1.0     1.0            0
# 407       1.0     1.0            0
# 462       1.0     1.0            0
# 565       1.0     1.0            0
# ...       ...     ...          ...
# 69277     1.0     1.0            0
# 69391     1.0     1.0            0
# 69482     1.0     1.0            1
# 69794     1.0     1.0            0
# 69953     1.0     1.0            0
#
# [668 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# age            0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# gender_Male    0
# dtype: int64

# %%
quan,qual = dpm.getQuanQual(df)

# %% [markdown]
# # Finding Co-Variance

# %%
dataset.cov()
# Out:
#                       age       height       weight        ap_hi  \
# age          5.786410e+06 -1399.676597 -2888.782613  2773.956342
# height      -1.399677e+03    52.842570    37.645899     2.381671
# weight      -2.888783e+03    37.645899   198.654041    16.870795
# ap_hi        2.773956e+03     2.381671    16.870795   382.858792
# ap_lo        2.794706e+04    25.493074     6.096383   346.122184
# cholesterol  1.204660e+02     0.028773     1.415203     0.609602
# gluc        -1.830163e+01    -0.264631     0.492086    -0.256578
# smoke        0.000000e+00     0.000000     0.000000     0.000000
# alco         0.000000e+00     0.000000     0.000000     0.000000
# active       0.000000e+00     0.000000     0.000000     0.000000
# cardio       0.000000e+00     0.000000     0.000000     0.000000
# gender_Male -2.223306e+01    -0.645943    -0.006257    -0.127355
#
#                      ap_lo  cholesterol       gluc  smoke  alco  active  \
# age           27947.063256   120.465957 -18.301628    0.0   0.0     0.0
# height           25.493074     0.028773  -0.264631    0.0   0.0     0.0
# weight            6.096383     1.415203   0.492086    0.0   0.0     0.0
# ap_hi           346.122184     0.609602  -0.256578    0.0   0.0     0.0
# ap_lo        141773.648583   -11.051226  -1.385577    0.0   0.0     0.0
# cholesterol     -11.051226     0.612996   0.139861    0.0   0.0     0.0
# gluc             -1.385577     0.139861   0.311449    0.0   0.0     0.0
# smoke             0.000000     0.000000   0.000000    0.0   0.0     0.0
# alco              0.000000     0.000000   0.000000    0.0   0.0     0.0
# active            0.000000     0.000000   0.000000    0.0   0.0     0.0
# cardio            0.000000     0.000000   0.000000    0.0   0.0     0.0
# gender_Male      -1.677491     0.019517   0.000350    0.0   0.0     0.0
#
#              cardio  gender_Male
# age             0.0   -22.233057
# height          0.0    -0.645943
# weight          0.0    -0.006257
# ap_hi           0.0    -0.127355
# ap_lo           0.0    -1.677491
# cholesterol     0.0     0.019517
# gluc            0.0     0.000350
# smoke           0.0     0.000000
# alco            0.0     0.000000
# active          0.0     0.000000
# cardio          0.0     0.000000
# gender_Male     0.0     0.071892

# %% [markdown]
# # Finding CorRelation

# %%
dataset.corr()
# Out:
#                   age    height    weight     ap_hi     ap_lo  cholesterol  \
# age          1.000000 -0.080044 -0.085204  0.058935  0.030856     0.063963
# height      -0.080044  1.000000  0.367432  0.016744  0.009314     0.005056
# weight      -0.085204  0.367432  1.000000  0.061174  0.001149     0.128245
# ap_hi        0.058935  0.016744  0.061174  1.000000  0.046980     0.039792
# ap_lo        0.030856  0.009314  0.001149  0.046980  1.000000    -0.037487
# cholesterol  0.063963  0.005056  0.128245  0.039792 -0.037487     1.000000
# gluc        -0.013633 -0.065231  0.062560 -0.023497 -0.006594     0.320092
# smoke             NaN       NaN       NaN       NaN       NaN          NaN
# alco              NaN       NaN       NaN       NaN       NaN          NaN
# active            NaN       NaN       NaN       NaN       NaN          NaN
# cardio            NaN       NaN       NaN       NaN       NaN          NaN
# gender_Male -0.034471 -0.331407 -0.001656 -0.024275 -0.016616     0.092971
#
#                  gluc  smoke  alco  active  cardio  gender_Male
# age         -0.013633    NaN   NaN     NaN     NaN    -0.034471
# height      -0.065231    NaN   NaN     NaN     NaN    -0.331407
# weight       0.062560    NaN   NaN     NaN     NaN    -0.001656
# ap_hi       -0.023497    NaN   NaN     NaN     NaN    -0.024275
# ap_lo       -0.006594    NaN   NaN     NaN     NaN    -0.016616
# cholesterol  0.320092    NaN   NaN     NaN     NaN     0.092971
# gluc         1.000000    NaN   NaN     NaN     NaN     0.002340
# smoke             NaN    NaN   NaN     NaN     NaN          NaN
# alco              NaN    NaN   NaN     NaN     NaN          NaN
# active            NaN    NaN   NaN     NaN     NaN          NaN
# cardio            NaN    NaN   NaN     NaN     NaN          NaN
# gender_Male  0.002340    NaN   NaN     NaN     NaN     1.000000

# %% [markdown]
# # Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(dataset[["age","active"]])
# Out:
#   variables       VIF
# 0       age   1.00000
# 1    active  67.30553

# %%
calc_vif(dataset[["cholesterol","active"]])
# Out:
#      variables       VIF
# 0  cholesterol  1.000000
# 1       active  5.160586

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(dataset)
